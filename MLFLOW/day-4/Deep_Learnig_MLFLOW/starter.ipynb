# %% [markdown]
# ### Quickstart: Compare runs, choose a model, and deploy it to a REST API
#
# In this quickstart, you will:
#
# - Run a hyperparameter sweep on a training script
#
# - Compare the results of the runs in the MLflow UI
#
# - Choose the best run and register it as a model
#
# - Deploy the model to a REST API
#
# - Build a container image suitable for deployment to a cloud platform

# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature
# Out:
# c:\Users\M.Rameez\miniconda3\envs\ml_py\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
## load the dataset
data=pd.read_csv(
    "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",
)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## Split the data into training,validation and test sets

train,test=train_test_split(data,test_size=0.25,random_state=42)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2835            6.3              0.25         0.22            3.30      0.048
# 1157            7.8              0.30         0.29           16.85      0.054
# 744             7.4              0.38         0.27            7.50      0.041
# 1448            7.4              0.16         0.49            1.20      0.055
# 3338            7.2              0.27         0.28           15.20      0.046
# ...             ...               ...          ...             ...        ...
# 4426            6.2              0.21         0.52            6.50      0.047
# 466             7.0              0.14         0.32            9.00      0.039
# 3092            7.6              0.27         0.52            3.20      0.043
# 3772            6.3              0.24         0.29           13.70      0.035
# 860             8.1              0.27         0.35            1.70      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2835                 41.0                 161.0  0.99256  3.16       0.50
# 1157                 23.0                 135.0  0.99980  3.16       0.38
# 744                  24.0                 160.0  0.99535  3.17       0.43
# 1448                 18.0                 150.0  0.99170  3.23       0.47
# 3338                  6.0                  41.0  0.99665  3.17       0.39
# ...                   ...                   ...      ...   ...        ...
# 4426                 28.0                 123.0  0.99418  3.22       0.49
# 466                  54.0                 141.0  0.99560  3.22       0.43
# 3092                 28.0                 152.0  0.99129  3.02       0.53
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  quality
# 2835     10.5        6
# 1157      9.0        6
# 744      10.0        5
# 1448     11.2        6
# 3338     10.9        6
# ...       ...      ...
# 4426      9.9        6
# 466       9.4        6
# 3092     11.4        6
# 3772     10.6        6
# 860      10.4        8
#
# [3673 rows x 12 columns]

# %%
train[['quality']].values.ravel()
# Out:
# array([6, 6, 5, ..., 6, 6, 8], dtype=int64)

# %%
train_x=train.drop(['quality'],axis=1).values
train_y=train[['quality']].values.ravel()

## test dataset
test_x=test.drop(['quality'],axis=1).values
test_y=test[['quality']].values.ravel()

## splitting this train data into train and validation

train_x,valid_x,train_y,valid_y=train_test_split(train_x,train_y,test_size=0.20,random_state=42)

signature=infer_signature(train_x,train_y)

# %%
np.mean(train_x,axis=0)
# Out:
# array([6.86621852e+00, 2.80377808e-01, 3.32597005e-01, 6.42164738e+00,
#        4.55513955e-02, 3.53556841e+01, 1.38792376e+02, 9.94074221e-01,
#        3.18919333e+00, 4.88396869e-01, 1.05005673e+01])

# %%
train_x.shape[1]
# Out:
# 11

# %%
### ANN Model

def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation='relu'),
            keras.layers.Dense(1)

        ]
    )

    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params wwith MLFLOW tracking
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)

}

# %%
mlflow.set_experiment("wine-quality")
with mlflow.start_run():
    # Conduct the hyperparameter search using Hyperopt
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )

    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# 2026/02/11 21:21:56 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/02/11 21:21:56 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/02/11 21:21:56 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/02/11 21:21:56 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/02/11 21:21:56 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/02/11 21:21:56 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# 2026/02/11 21:21:58 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/02/11 21:21:59 INFO mlflow.store.db.utils: Updating database tables
# 2026/02/11 21:21:59 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/02/11 21:21:59 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/02/11 21:21:59 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# 2026/02/11 21:22:00 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# 2026/02/11 21:22:00 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# 2026/02/11 21:22:01 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# 2026/02/11 21:22:01 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# 2026/02/11 21:22:01 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# 2026/02/11 21:22:02 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# 2026/02/11 21:22:02 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# 2026/02/11 21:22:03 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# 2026/02/11 21:22:03 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# 2026/02/11 21:22:03 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# 2026/02/11 21:22:04 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# 2026/02/11 21:22:04 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# 2026/02/11 21:22:04 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# 2026/02/11 21:22:05 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# 2026/02/11 21:22:05 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# 2026/02/11 21:22:06 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# 2026/02/11 21:22:06 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# 2026/02/11 21:22:06 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# 2026/02/11 21:22:07 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# 2026/02/11 21:22:07 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# 2026/02/11 21:22:08 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# 2026/02/11 21:22:09 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# 2026/02/11 21:22:09 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# 2026/02/11 21:22:10 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# 2026/02/11 21:22:11 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# 2026/02/11 21:22:11 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# 2026/02/11 21:22:11 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# 2026/02/11 21:22:12 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# 2026/02/11 21:22:13 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# 2026/02/11 21:22:13 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# 2026/02/11 21:22:14 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# 2026/02/11 21:22:14 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# 2026/02/11 21:22:15 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# 2026/02/11 21:22:16 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# 2026/02/11 21:22:17 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# 2026/02/11 21:22:18 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# 2026/02/11 21:22:19 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# 2026/02/11 21:22:20 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# 2026/02/11 21:22:21 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# 2026/02/11 21:22:21 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# 2026/02/11 21:22:24 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/02/11 21:22:24 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/02/11 21:22:24 INFO mlflow.tracking.fluent: Experiment with name 'wine-quality' does not exist. Creating a new experiment.
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1:06 1s/step - loss: 32.4922 - root_mean_squared_error: 5.7002
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.9500 - root_mean_squared_error: 5.7401
# 15/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 32.7843 - root_mean_squared_error: 5.7257
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 32.6930 - root_mean_squared_error: 5.7177
# 25/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.6271 - root_mean_squared_error: 5.7119
# 30/46 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 32.5538 - root_mean_squared_error: 5.7055
# 38/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.4498 - root_mean_squared_error: 5.6964
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.3642 - root_mean_squared_error: 5.6889
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 31.8726 - root_mean_squared_error: 5.6456 - val_loss: 30.6113 - val_root_mean_squared_error: 5.5328
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 31.5763 - root_mean_squared_error: 5.6193
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.2534 - root_mean_squared_error: 5.5904
# 21/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.8991 - root_mean_squared_error: 5.5585
# 30/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.6674 - root_mean_squared_error: 5.5376
# 38/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.4672 - root_mean_squared_error: 5.5194
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 29.3061 - root_mean_squared_error: 5.4135 - val_loss: 28.1280 - val_root_mean_squared_error: 5.3036
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 27.6232 - root_mean_squared_error: 5.2558
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.9369 - root_mean_squared_error: 5.2853
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.7807 - root_mean_squared_error: 5.2706
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.6589 - root_mean_squared_error: 5.2590
# 42/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.5160 - root_mean_squared_error: 5.2454
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 26.9404 - root_mean_squared_error: 5.1904 - val_loss: 25.8362 - val_root_mean_squared_error: 5.0829
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 25.6653 - root_mean_squared_error: 5.0661
#  8/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.4236 - root_mean_squared_error: 5.0422
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 25.8362 - root_mean_squared_error: 5.0829
#
#   0%|          | 0/4 [00:05<?, ?trial/s, best loss=?]
# 2026/02/11 21:22:32 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1:04 1s/step - loss: 36.3372 - root_mean_squared_error: 6.0280
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.3484 - root_mean_squared_error: 5.9448
# 14/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 33.1381 - root_mean_squared_error: 5.7508
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.3945 - root_mean_squared_error: 5.4942
# 29/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.5936 - root_mean_squared_error: 5.1100
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.4472 - root_mean_squared_error: 4.8833
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.7333 - root_mean_squared_error: 4.7001
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 14.2598 - root_mean_squared_error: 3.7762 - val_loss: 4.0714 - val_root_mean_squared_error: 2.0178
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 2.9429 - root_mean_squared_error: 1.7155
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4050 - root_mean_squared_error: 1.5468
# 15/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2577 - root_mean_squared_error: 1.4992
# 25/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5460 - root_mean_squared_error: 1.5890
# 33/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8031 - root_mean_squared_error: 1.6642
# 41/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9738 - root_mean_squared_error: 1.7137
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.3894 - root_mean_squared_error: 1.8410 - val_loss: 1.6865 - val_root_mean_squared_error: 1.2987
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 1.6091 - root_mean_squared_error: 1.2685
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5174 - root_mean_squared_error: 1.2313
# 18/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6155 - root_mean_squared_error: 1.2697
# 25/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7230 - root_mean_squared_error: 1.3100
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8029 - root_mean_squared_error: 1.3393
# 38/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8400 - root_mean_squared_error: 1.3534
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7569 - root_mean_squared_error: 1.3255 - val_loss: 1.0576 - val_root_mean_squared_error: 1.0284
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.8469 - root_mean_squared_error: 0.9203
#  9/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0250 - root_mean_squared_error: 1.0116
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0576 - root_mean_squared_error: 1.0284
#
#  25%|██▌       | 1/4 [00:56<02:33, 51.23s/trial, best loss: 5.082927703857422]
# 2026/02/11 21:23:22 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 44.4858 - root_mean_squared_error: 6.6698
# 14/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.8788 - root_mean_squared_error: 6.4688
# 24/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.6618 - root_mean_squared_error: 6.2077
# 33/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.7967 - root_mean_squared_error: 5.9614
# 42/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.1653 - root_mean_squared_error: 5.7228
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 20.3828 - root_mean_squared_error: 4.5147 - val_loss: 4.4094 - val_root_mean_squared_error: 2.0999
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 4.6405 - root_mean_squared_error: 2.1542
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0673 - root_mean_squared_error: 2.0155
# 13/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9052 - root_mean_squared_error: 1.9743
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7120 - root_mean_squared_error: 1.9241
# 30/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5458 - root_mean_squared_error: 1.8802
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3722 - root_mean_squared_error: 1.8323
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.6443 - root_mean_squared_error: 1.6261 - val_loss: 1.9277 - val_root_mean_squared_error: 1.3884
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 1.7917 - root_mean_squared_error: 1.3386
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7614 - root_mean_squared_error: 1.3255
# 21/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8703 - root_mean_squared_error: 1.3658
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8996 - root_mean_squared_error: 1.3769
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8786 - root_mean_squared_error: 1.3696
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7520 - root_mean_squared_error: 1.3236 - val_loss: 1.6108 - val_root_mean_squared_error: 1.2692
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.4261 - root_mean_squared_error: 1.1942
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6268 - root_mean_squared_error: 1.2750
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6108 - root_mean_squared_error: 1.2692
#
#  50%|█████     | 2/4 [01:32<01:26, 43.16s/trial, best loss: 1.0283911228179932]
# 2026/02/11 21:23:59 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1:16 2s/step - loss: 29.5040 - root_mean_squared_error: 5.4318
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.3403 - root_mean_squared_error: 3.4052
# 17/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7496 - root_mean_squared_error: 2.8218
# 22/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5447 - root_mean_squared_error: 2.6024
# 33/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9472 - root_mean_squared_error: 2.2875
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3072 - root_mean_squared_error: 2.1520
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.9816 - root_mean_squared_error: 1.4077 - val_loss: 0.6592 - val_root_mean_squared_error: 0.8119
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.5958 - root_mean_squared_error: 0.7719
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6019 - root_mean_squared_error: 0.7757
# 19/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6296 - root_mean_squared_error: 0.7932
# 28/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6367 - root_mean_squared_error: 0.7976
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6324 - root_mean_squared_error: 0.7950
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6276 - root_mean_squared_error: 0.7920
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6135 - root_mean_squared_error: 0.7833 - val_loss: 0.5821 - val_root_mean_squared_error: 0.7630
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.4541 - root_mean_squared_error: 0.6738
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5448 - root_mean_squared_error: 0.7374
# 17/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5799 - root_mean_squared_error: 0.7606
# 26/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5861 - root_mean_squared_error: 0.7649
# 32/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5867 - root_mean_squared_error: 0.7654
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5836 - root_mean_squared_error: 0.7635
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5716 - root_mean_squared_error: 0.7561 - val_loss: 0.5487 - val_root_mean_squared_error: 0.7407
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4438 - root_mean_squared_error: 0.6662
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5146 - root_mean_squared_error: 0.7168
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5487 - root_mean_squared_error: 0.7407
#
#  75%|███████▌  | 3/4 [02:10<00:40, 40.16s/trial, best loss: 1.0283911228179932]
# 2026/02/11 21:24:36 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 100%|██████████| 4/4 [02:42<00:00, 40.66s/trial, best loss: 0.7407491207122803]
# 2026/02/11 21:25:08 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Best parameters: {'lr': 0.09887286768495583, 'momentum': 0.4238548879397602}
# Best eval rmse: 0.7407491207122803

# %%
## Inferencing

from mlflow.models import validate_serving_input

model_uri = 'runs:/9e0b52639ab44e6a864f5bd2f460fe42/model'

# The logged model does not contain an input_example.
# Manually generate a serving payload to verify your model prior to deployment.
from mlflow.models import convert_input_example_to_serving_input

# Define INPUT_EXAMPLE via assignment with your own input example to the model
# A valid input example is a data instance suitable for pyfunc prediction
serving_payload = convert_input_example_to_serving_input(test_x)

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)

# %%
# Load model as a PyFuncModel.
model_uri = 'runs:/9e0b52639ab44e6a864f5bd2f460fe42/model'
loaded_model = mlflow.pyfunc.load_model(model_uri)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(test_x))

# %%
## Register in the model registry
mlflow.register_model(model_uri,"wine-quality")

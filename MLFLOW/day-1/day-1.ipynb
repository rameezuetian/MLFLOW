# %% [markdown]
# # MLFLOW TRACKING SERVER

# %%
import mlflow
# Out:
# c:\Users\M.Rameez\miniconda3\envs\ml_py\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check my localhost")

with mlflow.start_run():
    mlflow.log_metric("test" , 1)
    mlflow.log_metric("test2" , 2)
# Out:
# 2026/01/24 20:01:59 INFO mlflow.tracking.fluent: Experiment with name 'Check my localhost' does not exist. Creating a new experiment.
# 🏃 View run thundering-cow-517 at: http://127.0.0.1:5000/#/experiments/1/runs/149979aa5393493ebe9f642081a0cc11
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test3" , 3)
    mlflow.log_metric("test4" , 4)
# Out:
# 🏃 View run powerful-bass-668 at: http://127.0.0.1:5000/#/experiments/1/runs/adaa979da87d44ceaef26d5952bf31b7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
